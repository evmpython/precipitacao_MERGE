# %% [markdown]
# ---
#
# # **Download dos dados de precipitação do MERGE-CPTEC**
#
#
# ---
#
#
# **OBJETIVO:** Este Colab tem como objetivo baixar os dados de precipitação do produto MERGE do CPTEC. Os dados estão disponibilizados no [ftp](http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/) do CPTEC.
#
#
# ---
#
#
# **DADOS QUE SÃO BAIXADOS**:
#
# 1.   Arquivos diários (**DAILY**) de precipitação do produto MERGE:
#     - Exemplo: **MERGE_CPTEC_20220202.grib2**
# 2.   Arquivos horários (**HOURLY**) de precipitação do produto MERGE:
#     - Exemplo: **MERGE_CPTEC_2022021801.grib2**
#
# ---
#
# **PROCEDIMENTO REALIZADO:** Os seguintes procedimentos são realizados nesse código:
# 1.   Importação das bibliotecas
# 2.   Monta o drive
# 2.   São realizados os seguintes passos:
#      1. Define o intervalo de datas (**fazer mudanças aqui**)
#      2. Define as informações de entrada
#      3. Realiza o download dos dados
#
#
# ---
# **OBSERVAÇÕES IMPORTANTES**:
# 1. Definir o período dos dados
# 2. Alterar o nome (**dir_output**) do diretório de saída dos dados
#
#
# ---
# - **Realizado por:** Enrique V. Mattos - 01/03/2022
# - **Atualizado por:** Enrique V. Mattos - 05/07/2023
#
#
# ---

# %% [markdown]
# # **1° Passo:** Importando as bibliotecas

# %%
import os
import time as t
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# # **2° Passo:** Montando drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **PARTE 1):** Dados `diários`
#  - Exemplo: "MERGE_CPTEC_20220202.grib2"

# %% [markdown]
# - **>>> ALTERAÇÕES AQUI <<<**: Insira as informações necessárias

# %%
# definir a data inicial e final
anoi, mesi, diai = 2022, 2, 1 # ano, mes e dia inicial do período
anof, mesf, diaf = 2022, 2, 5 # ano, mes e dia final do período

# escolha o tipo de dado (tem duas opções: i) horária-DAILY e ii) mensal-HOURLY)
frequencia_chuva = 'DAILY'

# definir o caminho de saída
dir_output = '/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/'

# %% [markdown]
# - **Informações de entrada**

# %%
# informações sobre os dados
url_cptec = 'http://ftp.cptec.inpe.br/'
diretorio = f'modelos/tempo/MERGE/GPM/{frequencia_chuva}/'
codigo = 'MERGE_CPTEC'
extensao = 'grib2'

# %% [markdown]
# - **Download dos dados**

# %%
# Inicia o contador de tempo
start_time = t.time()

# Data desejada
date_in = datetime(anoi, mesi, diai)  # 2022-02-02 00:00:00
date_ini = date_in.strftime('%Y%m%d') # 20220202

date_en = datetime(anof, mesf, diaf)
date_end = date_en.strftime('%Y%m%d')

print('.... Processando Data ...:', date_ini, date_end)

# Download dos dados
for file in pd.date_range(date_ini, date_end, freq='d'):

    # Extrai ano e mes
    data = file.strftime('%Y%m%d')
    ano = file.strftime('%Y')
    mes = file.strftime('%m')

    # nome do arquivo
    filename = f'{codigo}_{data}.{extensao}'
    filename_total = os.path.join(url_cptec, diretorio, ano, mes, filename) # http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2020/10/

    #print(filename, filename_total)

    print('\n---------------------')
    print('Downloading FTP File:')
    print('---------------------')
    print('Model:MERGE / Tipo:' + frequencia_chuva)
    print('File:' + filename_total)
    print('---------------------')

    # !wget -c {filename_total} -P {dir_output}

    #break

# Contabiliza o tempo para baixar os dados
print('\nTempo de download dos dados:', round((t.time() - start_time),2), 'segundos.')
# Out:
# .... Processando Data ...: 20220201 20220205
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:DAILY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220201.grib2
# ---------------------
# --2023-07-05 17:25:36--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220201.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 449691 (439K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_20220201.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>] 439.15K   130KB/s    in 3.4s
#
# 2023-07-05 17:25:40 (130 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_20220201.grib2’ saved [449691/449691]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:DAILY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220202.grib2
# ---------------------
# --2023-07-05 17:25:40--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220202.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:DAILY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220203.grib2
# ---------------------
# --2023-07-05 17:25:41--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220203.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:DAILY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220204.grib2
# ---------------------
# --2023-07-05 17:25:41--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220204.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:DAILY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220205.grib2
# ---------------------
# --2023-07-05 17:25:42--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/02/MERGE_CPTEC_20220205.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 478251 (467K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_20220205.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>] 467.04K   116KB/s    in 4.0s
#
# 2023-07-05 17:25:46 (116 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_20220205.grib2’ saved [478251/478251]
#
#
# Tempo de download dos dados: 10.39 segundos.

# %% [markdown]
# # **PARTE 2):** Dados `horários`
#  - Exemplo: "MERGE_CPTEC_2022021801.grib2"

# %% [markdown]
# - **>>> ALTERAÇÕES AQUI <<<**: Insira as informações necessárias

# %%
# definir a data inicial e final
anoi, mesi, diai, hori = 2022, 2, 2, 0,  # ano, mes, dia e hora inicial do período
anof, mesf, diaf, horf = 2022, 2, 2, 23  # ano, mes, dia e hora final do período

# escolha o tipo de dado (tem duas opções: i) horária-DAILY e ii) mensal-HOURLY)
frequencia_chuva = 'HOURLY'

# definir o caminho de saída
dir_output = '/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/'

# %% [markdown]
# - **Informações de entrada**

# %%
# informações sobre os dados
url_cptec = 'http://ftp.cptec.inpe.br/'
diretorio = f'modelos/tempo/MERGE/GPM/{frequencia_chuva}/'
codigo = 'MERGE_CPTEC'
extensao = 'grib2'

# %% [markdown]
# - **Download dos dados**

# %%
# Inicia o contador de tempo
start_time = t.time()

# Data desejada
date_in = datetime(anoi, mesi, diai, hori)  # 2022-02-02 00
date_ini = date_in.strftime('%Y-%m-%d %H')  # 2022020200

date_en = datetime(anof, mesf, diaf, horf)
date_end = date_en.strftime('%Y-%m-%d %H')

print('.... Processando Data ...:', date_ini, date_end)

# Download dos dados
for file in pd.date_range(date_ini, date_end, freq='H'):

    # Extrai ano e mes
    data = file.strftime('%Y%m%d%H')
    ano = file.strftime('%Y')
    mes = file.strftime('%m')
    dia = file.strftime('%d')
    hor = file.strftime('%H')

    # nome do arquivo
    filename = f'{codigo}_{data}.{extensao}'
    filename_total = os.path.join(url_cptec, diretorio, ano, mes, dia, filename) # http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/18/

    print('\n---------------------')
    print('Downloading FTP File:')
    print('---------------------')
    print('Model:MERGE / Tipo:' + frequencia_chuva)
    print('File:' + filename_total)
    print('---------------------')

    # baixando o dado
    # !wget -c {filename_total} -P {dir_output}

# Contabiliza o tempo para baixar os dados
print('\nTempo de download dos dados:', round((t.time() - start_time),2), 'segundos.')
# Out:
# .... Processando Data ...: 2022-02-02 00 2022-02-02 23
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020200.grib2
# ---------------------
# --2023-07-05 17:28:15--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020200.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020201.grib2
# ---------------------
# --2023-07-05 17:28:16--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020201.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87939 (86K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020201.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  85.88K  58.5KB/s    in 1.5s
#
# 2023-07-05 17:28:18 (58.5 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020201.grib2’ saved [87939/87939]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020202.grib2
# ---------------------
# --2023-07-05 17:28:18--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020202.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92837 (91K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020202.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  90.66K   143KB/s    in 0.6s
#
# 2023-07-05 17:28:20 (143 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020202.grib2’ saved [92837/92837]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020203.grib2
# ---------------------
# --2023-07-05 17:28:20--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020203.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96427 (94K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020203.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  94.17K  94.7KB/s    in 1.0s
#
# 2023-07-05 17:28:21 (94.7 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020203.grib2’ saved [96427/96427]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020204.grib2
# ---------------------
# --2023-07-05 17:28:21--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020204.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98783 (96K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020204.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  96.47K   103KB/s    in 0.9s
#
# 2023-07-05 17:28:23 (103 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020204.grib2’ saved [98783/98783]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020205.grib2
# ---------------------
# --2023-07-05 17:28:23--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020205.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105398 (103K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020205.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>] 102.93K   119KB/s    in 0.9s
#
# 2023-07-05 17:28:24 (119 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020205.grib2’ saved [105398/105398]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020206.grib2
# ---------------------
# --2023-07-05 17:28:24--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020206.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88951 (87K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020206.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  86.87K   120KB/s    in 0.7s
#
# 2023-07-05 17:28:25 (120 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020206.grib2’ saved [88951/88951]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020207.grib2
# ---------------------
# --2023-07-05 17:28:26--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020207.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98444 (96K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020207.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  96.14K   107KB/s    in 0.9s
#
# 2023-07-05 17:28:27 (107 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020207.grib2’ saved [98444/98444]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020208.grib2
# ---------------------
# --2023-07-05 17:28:27--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020208.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100685 (98K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020208.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  98.33K  78.2KB/s    in 1.3s
#
# 2023-07-05 17:28:29 (78.2 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020208.grib2’ saved [100685/100685]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020209.grib2
# ---------------------
# --2023-07-05 17:28:29--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020209.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96276 (94K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020209.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  94.02K   106KB/s    in 0.9s
#
# 2023-07-05 17:28:30 (106 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020209.grib2’ saved [96276/96276]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020210.grib2
# ---------------------
# --2023-07-05 17:28:30--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020210.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98714 (96K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020210.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  96.40K   104KB/s    in 0.9s
#
# 2023-07-05 17:28:32 (104 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020210.grib2’ saved [98714/98714]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020211.grib2
# ---------------------
# --2023-07-05 17:28:32--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020211.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90636 (89K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020211.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  88.51K  91.4KB/s    in 1.0s
#
# 2023-07-05 17:28:33 (91.4 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020211.grib2’ saved [90636/90636]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020212.grib2
# ---------------------
# --2023-07-05 17:28:33--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020212.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99087 (97K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020212.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  96.76K   113KB/s    in 0.9s
#
# 2023-07-05 17:28:35 (113 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020212.grib2’ saved [99087/99087]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020213.grib2
# ---------------------
# --2023-07-05 17:28:35--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020213.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94721 (93K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020213.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  92.50K  93.0KB/s    in 1.0s
#
# 2023-07-05 17:28:36 (93.0 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020213.grib2’ saved [94721/94721]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020214.grib2
# ---------------------
# --2023-07-05 17:28:36--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020214.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60116 (59K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020214.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  58.71K  96.4KB/s    in 0.6s
#
# 2023-07-05 17:28:37 (96.4 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020214.grib2’ saved [60116/60116]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020215.grib2
# ---------------------
# --2023-07-05 17:28:37--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020215.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75276 (74K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020215.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  73.51K  97.5KB/s    in 0.8s
#
# 2023-07-05 17:28:39 (97.5 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020215.grib2’ saved [75276/75276]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020216.grib2
# ---------------------
# --2023-07-05 17:28:39--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020216.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81165 (79K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020216.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  79.26K  96.2KB/s    in 0.8s
#
# 2023-07-05 17:28:40 (96.2 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020216.grib2’ saved [81165/81165]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020217.grib2
# ---------------------
# --2023-07-05 17:28:40--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020217.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87438 (85K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020217.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  85.39K  85.5KB/s    in 1.0s
#
# 2023-07-05 17:28:42 (85.5 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020217.grib2’ saved [87438/87438]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020218.grib2
# ---------------------
# --2023-07-05 17:28:42--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020218.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75940 (74K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020218.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  74.16K   103KB/s    in 0.7s
#
# 2023-07-05 17:28:43 (103 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020218.grib2’ saved [75940/75940]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020219.grib2
# ---------------------
# --2023-07-05 17:28:43--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020219.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95498 (93K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020219.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  93.26K  91.6KB/s    in 1.0s
#
# 2023-07-05 17:28:45 (91.6 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020219.grib2’ saved [95498/95498]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020220.grib2
# ---------------------
# --2023-07-05 17:28:45--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020220.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101249 (99K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020220.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  98.88K  81.0KB/s    in 1.2s
#
# 2023-07-05 17:28:47 (81.0 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020220.grib2’ saved [101249/101249]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020221.grib2
# ---------------------
# --2023-07-05 17:28:47--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020221.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107307 (105K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020221.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>] 104.79K  76.0KB/s    in 1.4s
#
# 2023-07-05 17:28:49 (76.0 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020221.grib2’ saved [107307/107307]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020222.grib2
# ---------------------
# --2023-07-05 17:28:49--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020222.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82988 (81K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020222.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  81.04K  93.3KB/s    in 0.9s
#
# 2023-07-05 17:28:51 (93.3 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020222.grib2’ saved [82988/82988]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model:MERGE / Tipo:HOURLY
# File:http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020223.grib2
# ---------------------
# --2023-07-05 17:28:51--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/HOURLY/2022/02/02/MERGE_CPTEC_2022020223.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.141.22
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.141.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95693 (93K)
# Saving to: ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020223.grib2’
#
# MERGE_CPTEC_2022020 100%[===================>]  93.45K  72.1KB/s    in 1.3s
#
# 2023-07-05 17:28:52 (72.1 KB/s) - ‘/content/drive/MyDrive/PYHTON/00_GITHUB/11_Precipitacao_MERGE/output/MERGE_CPTEC_2022020223.grib2’ saved [95693/95693]
#
#
# Tempo de download dos dados: 37.91 segundos.
